# %% [markdown]
# # Finding Donors for *CharityML*
# ## EDA: univariate
# ### Kebei Jiang 05/17/2019

# %% [markdown]
# ### Goal
#
# The goal of this notebook is to do initial EDA of the data. More importantly, I am trying to follow this [instruction](https://www.analyticsvidhya.com/blog/2016/01/guide-data-exploration/#one) and later build my own EDA flow/template.

# %% [markdown]
# ### Get Started
#
# The dataset for this project originates from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Census+Income). The datset was donated by Ron Kohavi and Barry Becker, after being published in the article [_"Scaling Up the Accuracy of Naive-Bayes Classifiers: A Decision-Tree Hybrid"_](https://www.aaai.org/Papers/KDD/1996/KDD96-033.pdf).
#
# First thing first, I double checked the [origin](https://www.kaggle.com/uciml/adult-census-income) of the original dataset and made following observations.
# 1. It was extracted from 1994 Census bureau database and was used as an example in aforementioned paper.
# 2. The _'fnlwgt'_ feature is the number of people in full population the census takers believe that observation represents. It can be ignored for the purpose of this project.
# 3. The _'census.csv'_ dataset is about the same size as the dataset used in the paper, minus some records with missing or ill-formatted entries.

# %% [markdown]
# -----

# %% [markdown]
# ### 0, data head and description

# %%
# Import libraries necessary for this project
import numpy as np
import pandas as pd
from time import time
from IPython.display import display # Allows the use of display() for DataFrames

# Import libraries for visulization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the Census dataset
data = pd.read_csv("census.csv")

display(data.head(n=5))
display(data.describe())
print('Raw data has {} rows and {} columns.'.format(data.shape[0], data.shape[1]))
# Out:
#    age          workclass education_level  education-num       marital-status  \
# 0   39          State-gov       Bachelors           13.0        Never-married
# 1   50   Self-emp-not-inc       Bachelors           13.0   Married-civ-spouse
# 2   38            Private         HS-grad            9.0             Divorced
# 3   53            Private            11th            7.0   Married-civ-spouse
# 4   28            Private       Bachelors           13.0   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male        2174.0
# 1     Exec-managerial         Husband   White     Male           0.0
# 2   Handlers-cleaners   Not-in-family   White     Male           0.0
# 3   Handlers-cleaners         Husband   Black     Male           0.0
# 4      Prof-specialty            Wife   Black   Female           0.0
#
#    capital-loss  hours-per-week  native-country income
# 0           0.0            40.0   United-States  <=50K
# 1           0.0            13.0   United-States  <=50K
# 2           0.0            40.0   United-States  <=50K
# 3           0.0            40.0   United-States  <=50K
# 4           0.0            40.0            Cuba  <=50K
#                 age  education-num  capital-gain  capital-loss  hours-per-week
# count  45222.000000   45222.000000  45222.000000  45222.000000    45222.000000
# mean      38.547941      10.118460   1101.430344     88.595418       40.938017
# std       13.217870       2.552881   7506.430084    404.956092       12.007508
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       47.000000      13.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000
# Raw data has 45222 rows and 14 columns.

# %% [markdown]
# **observation**: no missing or ill-formatted entries. no cleansing needed.

# %% [markdown]
# -------

# %% [markdown]
# ### 1, Variable Identification

# %%
data.dtypes
# Out:
# age                  int64
# workclass           object
# education_level     object
# education-num      float64
# marital-status      object
# occupation          object
# relationship        object
# race                object
# sex                 object
# capital-gain       float64
# capital-loss       float64
# hours-per-week     float64
# native-country      object
# income              object
# dtype: object

# %%
for col in data.columns.values:
    print('{} has {} unique values:\n {}\n '.format(col, data[col].nunique(), data[col].unique()))
# Out:
# age has 74 unique values:
#  [39 50 38 53 28 37 49 52 31 42 30 23 32 34 25 43 40 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 47 46 36 79 27 18 33 76 55 61 70 64 71 66 51 58
#  26 17 60 90 75 65 77 62 63 67 74 72 69 68 73 81 78 88 80 84 83 85 82 86
#  89 87]
#
# workclass has 7 unique values:
#  [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' Self-emp-inc' ' Without-pay']
#
# education_level has 16 unique values:
#  [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' 7th-8th' ' Doctorate' ' Assoc-voc' ' Prof-school'
#  ' 5th-6th' ' 10th' ' Preschool' ' 12th' ' 1st-4th']
#
# education-num has 16 unique values:
#  [13.  9.  7. 14.  5. 10. 12.  4. 16. 11. 15.  3.  6.  1.  8.  2.]
#
# marital-status has 7 unique values:
#  [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
#
# occupation has 14 unique values:
#  [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Transport-moving' ' Farming-fishing'
#  ' Machine-op-inspct' ' Tech-support' ' Craft-repair' ' Protective-serv'
#  ' Armed-Forces' ' Priv-house-serv']
#
# relationship has 6 unique values:
#  [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
#
# race has 5 unique values:
#  [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
#
# sex has 2 unique values:
#  [' Male' ' Female']
#
# capital-gain has 121 unique values:
#  [ 2174.     0. 14084.  5178.  5013.  2407. 14344. 15024.  7688.  4064.
#   4386.  7298.  1409.  3674.  1055.  2050.  2176.   594. 20051.  6849.
#   4101.  8614.  3411.  2597. 25236.  4650.  2463.  3103. 10605.  2964.
#   3325.  2580.  3471.  4865. 99999.  6514.  1471.  2329.  2105.  2885.
#  10520.  2202.  2961. 27828.  6767.  2228.  1506. 13550.  2635.  5556.
#   4787.  3781.  3137.  3818.   914.   401.  2829.  2977.  4934.  2062.
#   2354.  3464.  5455. 15020.  1424.  3273. 22040.  4416. 10566.  4931.
#   7430. 34095.  6497.  3908.   114.  2346.  2907.  1151.  9386.  2414.
#   2290.  3418. 15831. 41310.  4508.  2538.  3456.  1848.  3887.  7896.
#   5721.  9562.  6418.  1455.  2036.  3942.  1831. 11678.  2936.  2993.
#   7443.  6360.  4687.  1797.  6723.  2009.  3432.  6097.  1639.  2653.
#  18481. 25124.  7978.   991.  1173.  2387.  5060.  1086.  1264.  7262.
#   1731.]
#
# capital-loss has 97 unique values:
#  [   0. 2042. 1408. 1902. 1887. 1719. 1762. 1564. 2179. 1816. 1980. 1977.
#  1876. 1340. 2206. 1741. 1485. 2339. 2415. 1380. 1721. 2051. 2377. 1669.
#  2352. 1672.  653. 2392. 1504. 1590. 1651. 1628. 1848. 2001. 1740. 2002.
#  1579. 2258. 1602. 2547. 2205. 1726. 2444. 1138. 2238.  625.  213. 1539.
#   880. 1668. 1092. 1594. 2231. 1844.  810. 2824. 2559. 2057. 1573. 1974.
#   974. 2174. 2149. 1735. 1258. 2603. 2282.  323. 2246. 1617. 1648. 1825.
#  3770. 1755. 3683. 2129. 4356. 2267. 2080. 2457.  419.  155. 3900. 2201.
#  1944. 2467. 2754. 2472. 3004. 1411. 1429. 3175. 1870. 1911. 1510. 1421.
#  2163.]
#
# hours-per-week has 96 unique values:
#  [40. 13. 16. 45. 50. 80. 30. 35. 60. 20. 52. 44. 15. 25. 43. 38. 55. 48.
#  58. 32. 70. 22. 56. 41. 28. 36. 24. 46.  2. 42. 12. 65.  1. 34. 75. 98.
#  33. 54. 10.  6. 64. 19. 18. 72.  8.  9. 47. 37. 21. 26. 14.  5.  7. 99.
#  53. 39. 62. 59. 57. 78. 90. 66. 11. 49. 84. 17. 68.  3. 27. 85. 31. 51.
#  77. 63. 23.  4. 87. 88. 73. 89. 97. 94. 29. 96. 67. 82. 86. 91. 81. 76.
#  92. 61. 74. 95. 79. 69.]
#
# native-country has 41 unique values:
#  [' United-States' ' Cuba' ' Jamaica' ' India' ' Mexico' ' Puerto-Rico'
#  ' Honduras' ' England' ' Canada' ' Germany' ' Iran' ' Philippines'
#  ' Poland' ' Columbia' ' Cambodia' ' Thailand' ' Ecuador' ' Laos'
#  ' Taiwan' ' Haiti' ' Portugal' ' Dominican-Republic' ' El-Salvador'
#  ' France' ' Guatemala' ' Italy' ' China' ' South' ' Japan' ' Yugoslavia'
#  ' Peru' ' Outlying-US(Guam-USVI-etc)' ' Scotland' ' Trinadad&Tobago'
#  ' Greece' ' Nicaragua' ' Vietnam' ' Hong' ' Ireland' ' Hungary'
#  ' Holand-Netherlands']
#
# income has 2 unique values:
#  ['<=50K' '>50K']

# %%
ft_num = data.select_dtypes(include=['int64','float64']).columns.values
ft_cat = data.select_dtypes(exclude=['int64','float64']).columns.values

#print(ft_num)
#print(ft_cat)

# %%
data['income_binary'] = [0 if x =='<=50K' else 1 for x in data['income']]
u, u_count = np.unique(data['income_binary'], return_counts=True)
plt.pie(u_count, labels=['<=50K', '>50K'], pctdistance=1.1, labeldistance=1.2)
plt.show()
data['income_binary'].describe()
# Out:
# count    45222.000000
# mean         0.247844
# std          0.431766
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: income_binary, dtype: float64

# %% [markdown]
# **observation**:
#  * skewed target variable, need to pay attetion to the skewness while modeling

# %% [markdown]
# -------

# %% [markdown]
#  ### 2a, Univariate Analysis: continuous

# %%
print('numerical features are: {}'.format(ft_num))
# Out:
# numerical features are: ['age' 'education-num' 'capital-gain' 'capital-loss' 'hours-per-week']

# %% [markdown]
# ### ages

# %%
age_bins = np.linspace(10, 90, 9)
age_lt50k = np.digitize(data[data['income']=='<=50K']['age'], age_bins)
age_gt50k = np.digitize(data[data['income']=='>50K']['age'], age_bins)
_, age_lt50k_counts = np.unique(age_lt50k, return_counts=True)
_, age_gt50k_counts = np.unique(age_gt50k, return_counts=True)

# %%
tmp = pd.DataFrame(np.column_stack([age_bins, age_lt50k_counts, age_gt50k_counts]), columns=['age_group', '<50k', '>50k'])
ax = tmp.plot.bar(x='age_group', stacked=True)
ax.set_xlabel('age_group')
ax.set_ylabel('counts')
ax.set_title('income counts by age group')
plt.show()

# %% [markdown]
# **observation**:
#  * people younger than 20 or older than 70 make less than the rest of the population, which agrees with common sense.

# %% [markdown]
# ### educations

# %%
edu_num_cts = data.groupby(['education-num'])['income'].value_counts().reset_index(name='count')
edu_num_lt50k = edu_num_cts.loc[edu_num_cts['income']=='<=50K']['count']
edu_num_gt50k = edu_num_cts.loc[edu_num_cts['income']=='>50K']['count']

# %%
tmp = pd.DataFrame(np.column_stack([edu_num_cts['education-num'].unique(), edu_num_lt50k, edu_num_gt50k, edu_num_gt50k.values/edu_num_lt50k.values]), columns=['education_num', '<50k', '>50k', 'ratio'])
#plt.subplot(211)
ax = tmp[tmp.columns.drop('ratio')].plot.barh(x='education_num', stacked=True, width=0.8)
ax.set_xlabel('education_num')
ax.set_ylabel('counts')
ax.set_title('income counts by education numbers')
plt.show()

# %%
ax = tmp[['education_num','ratio']].plot.barh(x='education_num', width=0.8)
ax.set_xlabel('education_num')
ax.set_ylabel('gt50K/lt50K')
ax.set_title('ratio gt50K/lt50K by education numbers')
plt.show()

# %%
edu_lvl_cts = data.groupby(['education_level'])['income'].value_counts().reset_index(name='count')
edu_lvl_lt50k = edu_lvl_cts.loc[edu_lvl_cts['income']=='<=50K']['count']
edu_lvl_gt50k = edu_lvl_cts.loc[edu_lvl_cts['income']=='>50K']['count']

tmp = pd.DataFrame(np.column_stack([edu_lvl_cts['education_level'].unique(), edu_lvl_lt50k, edu_lvl_gt50k]), columns=['education_level', '<50k', '>50k'])
#plt.subplot(211)
ax = tmp.plot.barh(x='education_level', stacked=True, width=0.8)
ax.set_xlabel('education_level')
ax.set_ylabel('counts')
ax.set_title('income counts by education level')
plt.show()

# %% [markdown]
# **observation**:
#  *  _education-level_ and _education-num_ carry the same information, can drop either one.
#  *  higher educational level, higher chance of earning more than 50K

# %% [markdown]
# ### capital investments

# %%
(data['capital-gain']*data['capital-loss']).sum()
# Out:
# 0.0

# %% [markdown]
# * gain and loss cannot be both non-zero, which means we are dealing with the _net_ income from capital investment.
# * people with zero gain and loss are simply outta market
# **Q**: shall we combine these two into one? i.e., _capital = _capital-gain + (-1)*capital-loss_? We can think about it during correlation QC.
#
# how many zeros do we have?

# %%
fig = plt.figure(figsize = (11,5))

for i, ft in enumerate(['capital-gain', 'capital-loss']):
    count1 = np.sum([x == 0 for x in data[ft]])
    count2 = np.sum([x != 0 for x in data[ft]])
    
    radius = 1  # the whole dataset
    
    ax = fig.add_subplot(1, 2, i+1)
    ax.pie([count1, count2], labels=['zero', 'non-zero'], autopct='%.0f%%', shadow=False, explode=(0, 0.1), radius=radius)
    ax.set_title('ratio of zero values for feature {}'.format(ft))

# %% [markdown]
# and to visualize their distributions:

# %%
# Create figure
fig = plt.figure(figsize = (11,5))

# Skewed feature plotting
for i, feature in enumerate(['capital-gain','capital-loss']):
    ax = fig.add_subplot(1, 2, i+1)
    ax.hist(data[feature], bins = 25, color = '#00A0A0')
    ax.set_title("'%s' Feature Distribution"%(feature), fontsize = 14)
    ax.set_xlabel("Value")
    ax.set_ylabel("Number of Records")
    ax.set_ylim((0, 2000))
    ax.set_yticks([0, 500, 1000, 1500, 2000])
    ax.set_yticklabels([0, 500, 1000, 1500, ">2000"])

# %% [markdown]
# The distribution looks extremely skewed because of the zero values. Shall we treat the zero values separately?

# %%
import operator as ops

fig = plt.figure(figsize = (11,5))

for i, op in enumerate([ops.eq, ops.ne]):
    for j, ft in enumerate(['capital-gain', 'capital-loss']):
        count = data[op(data[ft],0)]['income'].value_counts()

        radius = 2*np.sqrt(np.sum(count)/data.shape[0])  # size of the pie is proportional to the size of the dataset

        ax = fig.add_subplot(2, 2, i*2+j+1)
        ax.pie(count, labels=['>50K', '<=50K'], radius=radius, autopct='%.0f%%', shadow=False, explode=(0, 0.1))
        ax.set_title('{} is {} zero'.format((ft), op(0,0)), loc='center', pad=30)

plt.subplots_adjust(hspace=1, wspace=0.35)

# %% [markdown]
# The ratios of income classes are quite different when capital is not zero. This may suggest removing zero values or create a new category.
# Finally, let's look at the distribution of these two features with zero values removed.

# %%
import seaborn as sns
data['capital-gain-digitized']=data['capital-gain']//2000
data['capital-loss-digitized']=data['capital-loss']//200

fig = plt.figure(figsize = (13,4))
plt.subplot(121)
ax = sns.countplot(x='capital-gain-digitized', hue='income', data=data[~data['capital-gain'].isin([0])])
ax.set(xlabel='capital-gain/2000')
plt.legend(loc='upper right')
plt.subplot(122)
ax = sns.countplot(x='capital-loss-digitized', hue='income', data=data[~data['capital-loss'].isin([0])])
ax.set(xlabel='capital-loss/200')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# A few things came to my notice:
#  * people with high _capital-gain_ tend to earn more income; however, there're a few low incomers which can be potential outliers
#  * _capital-loss_ is not a good indicator for income classes

# %% [markdown]
# **Observations**
#  * gain and loss are the net income from capital investment. People with zero gain and loss are simply outta market. (May consider combining these two into one, i.e., _capital = capital-gain + (-1)*capital-loss._ )
#  * The ratios of income classes are quite different when capital is not zero. This may suggest removing zero values or create a new category.
#  * Possible outliers with high _capital-gain_ but low income.

# %% [markdown]
# ### hours-per-week

# %%
data['hours-per-week-digitized'] = data['hours-per-week']//10
sns.countplot(x='hours-per-week-digitized', hue='income', data=data)
plt.show()

# %%
# to plot the ratio between two income classes by 'hours-per-week-digitized'
# 'sum' counts the '>50K' occurrence; 'count' counts both cases
tmp = data.groupby(['hours-per-week-digitized'])['income_binary'].agg(['sum', 'count'])
tmp['ratio'] = tmp['sum']/tmp['count']*100
print(tmp.head())

plt.scatter(tmp.index.values, tmp['ratio'])
plt.xlabel('weekly working time in unit of 10hour')
plt.ylabel('percentage of people making >50K')
plt.xticks(range(10))
plt.show()
# Out:
#                            sum  count      ratio
# hours-per-week-digitized
# 0.0                         45    445  10.112360
# 1.0                         89   1555   5.723473
# 2.0                        195   3068   6.355932
# 3.0                        645   5019  12.851166
# 4.0                       6241  25840  24.152477

# %% [markdown]
# **Observations**
#  * People working more than 40 hours tend to have higher incomes, which makes sense
#  * are the working hours and _occupation_ significantly correlated? need to check in later sections

# %% [markdown]
# **groupby tricks**
#  * [unstack()](#another_cell)
#  * https://stackoverflow.com/questions/23377108/pandas-percentage-of-total-with-groupby
#  * https://stackoverflow.com/questions/19384532/get-statistics-for-each-group-such-as-count-mean-etc-using-pandas-groupby
#  * https://stackoverflow.com/questions/33217702/groupby-in-pandas-with-different-functions-for-different-columns
#  * https://stackoverflow.com/questions/22407798/how-to-reset-a-dataframes-indexes-for-all-groups-in-one-step

# %% [markdown]
#  ### 2b, Univariate Analysis: categorical

# %%
ft_cat
# Out:
# array(['workclass', 'education_level', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'income'],
#       dtype=object)

# %% [markdown]
# ### Wrok class

# %% [markdown]
# See how work class is distributed and how is it related to income classes. Meanwhile, the _unstack()_ function is very handy.<a id='another_cell'></a>

# %%
grouped = data.groupby(['workclass', 'income'])['income'].agg('count')
print(type(grouped))
display(grouped)
grouped = grouped.unstack()   # very important trick
display(grouped)     # print won't work here
print(grouped.index)
# Out:
# <class 'pandas.core.series.Series'>
# workclass          income
#  Federal-gov       <=50K       857
#                    >50K        549
#  Local-gov         <=50K      2185
#                    >50K        915
#  Private           <=50K     26056
#                    >50K       7251
#  Self-emp-inc      <=50K       734
#                    >50K        912
#  Self-emp-not-inc  <=50K      2737
#                    >50K       1059
#  State-gov         <=50K      1426
#                    >50K        520
#  Without-pay       <=50K        19
#                    >50K          2
# Name: income, dtype: int64
# income             <=50K  >50K
# workclass
#  Federal-gov         857   549
#  Local-gov          2185   915
#  Private           26056  7251
#  Self-emp-inc        734   912
#  Self-emp-not-inc   2737  1059
#  State-gov          1426   520
#  Without-pay          19     2
# Index([' Federal-gov', ' Local-gov', ' Private', ' Self-emp-inc',
#        ' Self-emp-not-inc', ' State-gov', ' Without-pay'],
#       dtype='object', name='workclass')

# %%
fig = plt.figure(figsize = (4,4))

grouped.plot.bar(stacked=True, color=['red','navy'])
plt.xticks(rotation=45)
plt.show()

# %%
grouped['>50K_proportion'] = np.divide(grouped['>50K'], grouped['>50K'] + grouped['<=50K'])
grouped.plot.bar(y='>50K_proportion', color='navy', figsize = (6,4))
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Observations**
#
# Apparently, we have a lot of 'private' workers. This give me a better understanding of the classes:
#  * 'gov' related: federal level has higher income than local and state
#  * 'private' is privately owned companies, they make up most of the population and has the 2nd lowest >50K proportion.
#  * the difference between 'self-emp-inc' and 'self-emp-not-inc' are summarized in this [article](https://smallbiztrends.com/2013/11/incorporated-versus-unincorporated-self-employment.html).
#  * 'Without-pay' should be related to age?

# %%
data[(data['workclass']==' Without-pay')]
# Out:
#        age     workclass education_level  education-num  \
# 1748    65   Without-pay         7th-8th            4.0
# 8550    19   Without-pay         HS-grad            9.0
# 14390   21   Without-pay         HS-grad            9.0
# 14535   22   Without-pay         HS-grad            9.0
# 15566   46   Without-pay         HS-grad            9.0
# 18600   65   Without-pay         HS-grad            9.0
# 20329   52   Without-pay         HS-grad            9.0
# 20584   19   Without-pay         HS-grad            9.0
# 22802   62   Without-pay      Assoc-acdm           12.0
# 23630   29   Without-pay    Some-college           10.0
# 25713   72   Without-pay         HS-grad            9.0
# 26725   68   Without-pay    Some-college           10.0
# 27022   67   Without-pay         HS-grad            9.0
# 29887   62   Without-pay    Some-college           10.0
# 32894   19   Without-pay         HS-grad            9.0
# 33098   74   Without-pay         7th-8th            4.0
# 36131   51   Without-pay      Assoc-acdm           12.0
# 38393   64   Without-pay         HS-grad            9.0
# 40001   50   Without-pay         HS-grad            9.0
# 42976   39   Without-pay         HS-grad            9.0
# 43149   27   Without-pay         HS-grad            9.0
#
#                marital-status          occupation relationship  \
# 1748                  Widowed     Farming-fishing    Unmarried
# 8550            Never-married     Farming-fishing    Own-child
# 14390           Never-married        Craft-repair    Own-child
# 14535           Never-married   Handlers-cleaners    Own-child
# 15566      Married-civ-spouse   Machine-op-inspct         Wife
# 18600      Married-civ-spouse    Transport-moving      Husband
# 20329      Married-civ-spouse        Adm-clerical         Wife
# 20584           Never-married     Farming-fishing    Own-child
# 22802      Married-civ-spouse     Farming-fishing      Husband
# 23630      Married-civ-spouse     Farming-fishing    Own-child
# 25713      Married-civ-spouse       Other-service      Husband
# 26725   Married-spouse-absent     Farming-fishing    Unmarried
# 27022      Married-civ-spouse        Adm-clerical      Husband
# 29887      Married-civ-spouse        Adm-clerical         Wife
# 32894           Never-married       Other-service    Own-child
# 33098      Married-civ-spouse     Farming-fishing      Husband
# 36131      Married-civ-spouse               Sales      Husband
# 38393      Married-civ-spouse   Handlers-cleaners      Husband
# 40001      Married-civ-spouse   Machine-op-inspct    Own-child
# 42976      Married-civ-spouse     Exec-managerial      Husband
# 43149           Never-married     Farming-fishing    Own-child
#
#                       race      sex  capital-gain  capital-loss  \
# 1748                 White   Female           0.0           0.0
# 8550                 White     Male           0.0           0.0
# 14390                Black     Male           0.0           0.0
# 14535                White     Male        4416.0           0.0
# 15566                White   Female           0.0           0.0
# 18600                White     Male        2414.0           0.0
# 20329                White   Female           0.0           0.0
# 20584                White     Male           0.0           0.0
# 22802                White     Male           0.0           0.0
# 23630                White     Male           0.0           0.0
# 25713                White     Male           0.0           0.0
# 26725                White   Female           0.0           0.0
# 27022   Asian-Pac-Islander     Male           0.0           0.0
# 29887                White   Female           0.0           0.0
# 32894                White     Male           0.0           0.0
# 33098                White     Male           0.0           0.0
# 36131                White     Male           0.0           0.0
# 38393                White     Male           0.0           0.0
# 40001                White   Female           0.0        1887.0
# 42976                White     Male           0.0           0.0
# 43149                White   Female           0.0           0.0
#
#        hours-per-week  native-country income  income_binary  \
# 1748             50.0   United-States  <=50K              0
# 8550             20.0   United-States  <=50K              0
# 14390            40.0   United-States  <=50K              0
# 14535            40.0   United-States  <=50K              0
# 15566            25.0   United-States  <=50K              0
# 18600            20.0   United-States  <=50K              0
# 20329            30.0   United-States  <=50K              0
# 20584            10.0   United-States  <=50K              0
# 22802            50.0   United-States  <=50K              0
# 23630            65.0   United-States  <=50K              0
# 25713            55.0   United-States  <=50K              0
# 26725            25.0   United-States  <=50K              0
# 27022            12.0     Philippines  <=50K              0
# 29887            16.0   United-States  <=50K              0
# 32894            10.0   United-States  <=50K              0
# 33098            20.0   United-States  <=50K              0
# 36131            45.0   United-States  <=50K              0
# 38393            60.0   United-States   >50K              1
# 40001            40.0   United-States   >50K              1
# 42976            40.0   United-States  <=50K              0
# 43149            40.0   United-States  <=50K              0
#
#        capital-gain-digitized  capital-loss-digitized  \
# 1748                      0.0                     0.0
# 8550                      0.0                     0.0
# 14390                     0.0                     0.0
# 14535                     2.0                     0.0
# 15566                     0.0                     0.0
# 18600                     1.0                     0.0
# 20329                     0.0                     0.0
# 20584                     0.0                     0.0
# 22802                     0.0                     0.0
# 23630                     0.0                     0.0
# 25713                     0.0                     0.0
# 26725                     0.0                     0.0
# 27022                     0.0                     0.0
# 29887                     0.0                     0.0
# 32894                     0.0                     0.0
# 33098                     0.0                     0.0
# 36131                     0.0                     0.0
# 38393                     0.0                     0.0
# 40001                     0.0                     9.0
# 42976                     0.0                     0.0
# 43149                     0.0                     0.0
#
#        hours-per-week-digitized
# 1748                        5.0
# 8550                        2.0
# 14390                       4.0
# 14535                       4.0
# 15566                       2.0
# 18600                       2.0
# 20329                       3.0
# 20584                       1.0
# 22802                       5.0
# 23630                       6.0
# 25713                       5.0
# 26725                       2.0
# 27022                       1.0
# 29887                       1.0
# 32894                       1.0
# 33098                       2.0
# 36131                       4.0
# 38393                       6.0
# 40001                       4.0
# 42976                       4.0
# 43149                       4.0

# %% [markdown]
# ### marital-status

# %%
grouped = data.groupby(['marital-status', 'income'])['income'].agg('count')
grouped = grouped.unstack()   # very important trick
display(grouped)     # print won't work here
# Out:
# income                  <=50K  >50K
# marital-status
#  Divorced                5642   655
#  Married-AF-spouse         18    14
#  Married-civ-spouse     11491  9564
#  Married-spouse-absent    498    54
#  Never-married          13897   701
#  Separated               1312    99
#  Widowed                 1156   121

# %%
fig = plt.figure(figsize = (4,4))
grouped.plot.bar(stacked=True, color=['red','navy'])
plt.xticks(rotation=90)
plt.show()

# %%
data[data['marital-status']==' Married-spouse-absent']
# Out:
#        age          workclass education_level  education-num  \
# 6       49            Private             9th            5.0
# 162     27            Private         HS-grad            9.0
# 322     56            Private      Assoc-acdm           12.0
# 337     22            Private         HS-grad            9.0
# 400     40   Self-emp-not-inc       Bachelors           13.0
# 428     50            Private         1st-4th            2.0
# 447     41            Private         HS-grad            9.0
# 448     25            Private    Some-college           10.0
# 471     49            Private       Assoc-voc           11.0
# 574     47            Private             9th            5.0
# 706     31          State-gov    Some-college           10.0
# 855     33            Private         1st-4th            2.0
# 949     48       Self-emp-inc         Masters           14.0
# 1007    31            Private       Doctorate           16.0
# 1232    57            Private         Masters           14.0
# 1359    43   Self-emp-not-inc         HS-grad            9.0
# 1388    25            Private    Some-college           10.0
# 1626    29            Private         HS-grad            9.0
# 1639    42          Local-gov       Bachelors           13.0
# 1643    66            Private         5th-6th            3.0
# 1782    35            Private       Bachelors           13.0
# 1819    40            Private       Bachelors           13.0
# 1839    75   Self-emp-not-inc         Masters           14.0
# 1851    23            Private    Some-college           10.0
# 1887    24            Private       Bachelors           13.0
# 1937    26            Private    Some-college           10.0
# 2129    42            Private    Some-college           10.0
# 2152    41            Private            11th            7.0
# 2190    63            Private         7th-8th            4.0
# 2300    31   Self-emp-not-inc       Bachelors           13.0
# ...    ...                ...             ...            ...
# 42667   17            Private            10th            6.0
# 42674   42   Self-emp-not-inc         HS-grad            9.0
# 42700   55        Federal-gov       Bachelors           13.0
# 42743   47            Private       Bachelors           13.0
# 42845   32   Self-emp-not-inc            10th            6.0
# 42956   57            Private         HS-grad            9.0
# 42962   36            Private       Bachelors           13.0
# 43128   33            Private         HS-grad            9.0
# 43350   35            Private       Assoc-voc           11.0
# 43375   38   Self-emp-not-inc    Some-college           10.0
# 43398   26            Private         5th-6th            3.0
# 43438   27            Private    Some-college           10.0
# 43501   43          Local-gov         Masters           14.0
# 43503   29            Private         HS-grad            9.0
# 43563   30            Private         HS-grad            9.0
# 43590   21            Private         HS-grad            9.0
# 43599   28            Private         HS-grad            9.0
# 43651   31            Private       Bachelors           13.0
# 43727   37   Self-emp-not-inc      Assoc-acdm           12.0
# 43793   44            Private       Bachelors           13.0
# 43876   24            Private    Some-college           10.0
# 44104   35   Self-emp-not-inc    Some-college           10.0
# 44132   35   Self-emp-not-inc         HS-grad            9.0
# 44313   55            Private            10th            6.0
# 44360   19            Private         HS-grad            9.0
# 44671   22            Private         HS-grad            9.0
# 44839   36          Local-gov         HS-grad            9.0
# 44849   48            Private      Assoc-acdm           12.0
# 44957   80   Self-emp-not-inc         7th-8th            4.0
# 45006   24          Local-gov         HS-grad            9.0
#
#                marital-status          occupation     relationship  \
# 6       Married-spouse-absent       Other-service    Not-in-family
# 162     Married-spouse-absent               Sales        Unmarried
# 322     Married-spouse-absent       Other-service    Not-in-family
# 337     Married-spouse-absent               Sales    Not-in-family
# 400     Married-spouse-absent      Prof-specialty    Not-in-family
# 428     Married-spouse-absent        Craft-repair        Unmarried
# 447     Married-spouse-absent        Craft-repair        Unmarried
# 448     Married-spouse-absent        Adm-clerical        Own-child
# 471     Married-spouse-absent   Handlers-cleaners        Unmarried
# 574     Married-spouse-absent   Handlers-cleaners        Unmarried
# 706     Married-spouse-absent       Other-service   Other-relative
# 855     Married-spouse-absent     Priv-house-serv    Not-in-family
# 949     Married-spouse-absent               Sales    Not-in-family
# 1007    Married-spouse-absent      Prof-specialty    Not-in-family
# 1232    Married-spouse-absent      Prof-specialty    Not-in-family
# 1359    Married-spouse-absent        Craft-repair    Not-in-family
# 1388    Married-spouse-absent      Prof-specialty        Unmarried
# 1626    Married-spouse-absent     Protective-serv    Not-in-family
# 1639    Married-spouse-absent      Prof-specialty    Not-in-family
# 1643    Married-spouse-absent   Handlers-cleaners        Unmarried
# 1782    Married-spouse-absent     Exec-managerial        Unmarried
# 1819    Married-spouse-absent      Prof-specialty    Not-in-family
# 1839    Married-spouse-absent      Prof-specialty    Not-in-family
# 1851    Married-spouse-absent       Other-service    Not-in-family
# 1887    Married-spouse-absent      Prof-specialty        Own-child
# 1937    Married-spouse-absent        Craft-repair   Other-relative
# 2129    Married-spouse-absent      Prof-specialty    Not-in-family
# 2152    Married-spouse-absent   Machine-op-inspct    Not-in-family
# 2190    Married-spouse-absent       Other-service        Unmarried
# 2300    Married-spouse-absent     Exec-managerial    Not-in-family
# ...                       ...                 ...              ...
# 42667   Married-spouse-absent       Other-service   Other-relative
# 42674   Married-spouse-absent        Craft-repair    Not-in-family
# 42700   Married-spouse-absent     Exec-managerial    Not-in-family
# 42743   Married-spouse-absent     Exec-managerial    Not-in-family
# 42845   Married-spouse-absent        Craft-repair        Own-child
# 42956   Married-spouse-absent    Transport-moving    Not-in-family
# 42962   Married-spouse-absent     Exec-managerial    Not-in-family
# 43128   Married-spouse-absent        Adm-clerical   Other-relative
# 43350   Married-spouse-absent   Machine-op-inspct    Not-in-family
# 43375   Married-spouse-absent       Other-service        Unmarried
# 43398   Married-spouse-absent     Priv-house-serv   Other-relative
# 43438   Married-spouse-absent     Exec-managerial    Not-in-family
# 43501   Married-spouse-absent      Prof-specialty        Unmarried
# 43503   Married-spouse-absent   Handlers-cleaners    Not-in-family
# 43563   Married-spouse-absent       Other-service        Unmarried
# 43590   Married-spouse-absent   Machine-op-inspct    Not-in-family
# 43599   Married-spouse-absent       Other-service    Not-in-family
# 43651   Married-spouse-absent      Prof-specialty    Not-in-family
# 43727   Married-spouse-absent     Farming-fishing    Not-in-family
# 43793   Married-spouse-absent               Sales        Unmarried
# 43876   Married-spouse-absent     Farming-fishing        Unmarried
# 44104   Married-spouse-absent        Craft-repair    Not-in-family
# 44132   Married-spouse-absent       Other-service    Not-in-family
# 44313   Married-spouse-absent        Craft-repair    Not-in-family
# 44360   Married-spouse-absent       Other-service        Own-child
# 44671   Married-spouse-absent               Sales        Unmarried
# 44839   Married-spouse-absent     Protective-serv    Not-in-family
# 44849   Married-spouse-absent        Craft-repair    Not-in-family
# 44957   Married-spouse-absent     Farming-fishing        Unmarried
# 45006   Married-spouse-absent   Machine-op-inspct        Unmarried
#
#                       race      sex  capital-gain  capital-loss  \
# 6                    Black   Female           0.0           0.0
# 162                  White   Female           0.0           0.0
# 322                  White     Male           0.0           0.0
# 337                  White     Male           0.0           0.0
# 400                  White   Female        2174.0           0.0
# 428                  White     Male           0.0           0.0
# 447                  White   Female           0.0           0.0
# 448                  Black   Female           0.0           0.0
# 471                  White     Male           0.0        1380.0
# 574                  White     Male           0.0           0.0
# 706                  White     Male           0.0           0.0
# 855                  White   Female           0.0           0.0
# 949     Asian-Pac-Islander     Male           0.0           0.0
# 1007    Asian-Pac-Islander     Male           0.0           0.0
# 1232                 White   Female           0.0           0.0
# 1359                 White     Male           0.0           0.0
# 1388                 Black     Male           0.0           0.0
# 1626                 White     Male           0.0           0.0
# 1639                 White   Female        8614.0           0.0
# 1643                 White   Female           0.0           0.0
# 1782                 White   Female           0.0           0.0
# 1819    Asian-Pac-Islander     Male       13550.0           0.0
# 1839                 White   Female           0.0           0.0
# 1851                 White   Female           0.0           0.0
# 1887                 White   Female           0.0           0.0
# 1937                 Black   Female           0.0           0.0
# 2129                 White     Male           0.0           0.0
# 2152                 White     Male           0.0           0.0
# 2190    Amer-Indian-Eskimo   Female           0.0           0.0
# 2300                 White     Male           0.0        1980.0
# ...                    ...      ...           ...           ...
# 42667                White     Male           0.0           0.0
# 42674                White   Female           0.0           0.0
# 42700                Black     Male           0.0           0.0
# 42743                White   Female       27828.0           0.0
# 42845                White     Male           0.0           0.0
# 42956                White     Male           0.0           0.0
# 42962                White     Male       10520.0           0.0
# 43128                White   Female           0.0           0.0
# 43350                Black     Male           0.0           0.0
# 43375                White   Female           0.0           0.0
# 43398                White   Female           0.0           0.0
# 43438                White   Female           0.0           0.0
# 43501                White   Female        7430.0           0.0
# 43503   Amer-Indian-Eskimo     Male           0.0           0.0
# 43563                Black   Female           0.0           0.0
# 43590                White   Female           0.0           0.0
# 43599   Asian-Pac-Islander   Female           0.0           0.0
# 43651   Asian-Pac-Islander     Male           0.0           0.0
# 43727                White     Male           0.0           0.0
# 43793   Asian-Pac-Islander     Male           0.0           0.0
# 43876                White   Female           0.0           0.0
# 44104                White     Male           0.0           0.0
# 44132                White   Female           0.0           0.0
# 44313                White     Male           0.0           0.0
# 44360                White   Female           0.0           0.0
# 44671                White   Female           0.0           0.0
# 44839                White     Male           0.0           0.0
# 44849                White     Male           0.0           0.0
# 44957                White     Male           0.0           0.0
# 45006                White   Female        2036.0           0.0
#
#        hours-per-week       native-country income  income_binary  \
# 6                16.0              Jamaica  <=50K              0
# 162              25.0        United-States  <=50K              0
# 322              25.0                 Iran  <=50K              0
# 337              55.0        United-States  <=50K              0
# 400              40.0        United-States  <=50K              0
# 428              40.0        United-States  <=50K              0
# 447              40.0        United-States  <=50K              0
# 448              20.0        United-States  <=50K              0
# 471              42.0        United-States  <=50K              0
# 574              40.0          El-Salvador  <=50K              0
# 706              40.0        United-States  <=50K              0
# 855              40.0            Guatemala  <=50K              0
# 949              50.0                India  <=50K              0
# 1007             60.0                China  <=50K              0
# 1232             40.0        United-States  <=50K              0
# 1359             40.0        United-States  <=50K              0
# 1388             40.0        United-States  <=50K              0
# 1626             40.0        United-States  <=50K              0
# 1639             45.0        United-States   >50K              1
# 1643             40.0          Puerto-Rico  <=50K              0
# 1782             40.0        United-States  <=50K              0
# 1819             40.0             Cambodia   >50K              1
# 1839             50.0        United-States  <=50K              0
# 1851             50.0        United-States  <=50K              0
# 1887             40.0        United-States  <=50K              0
# 1937             35.0   Dominican-Republic  <=50K              0
# 2129             40.0        United-States   >50K              1
# 2152             40.0            Guatemala  <=50K              0
# 2190             40.0        United-States  <=50K              0
# 2300             60.0        United-States  <=50K              0
# ...               ...                  ...    ...            ...
# 42667            40.0        United-States  <=50K              0
# 42674            40.0        United-States  <=50K              0
# 42700            40.0        United-States   >50K              1
# 42743            60.0        United-States   >50K              1
# 42845            16.0        United-States  <=50K              0
# 42956            40.0        United-States  <=50K              0
# 42962            40.0              Ireland   >50K              1
# 43128            32.0        United-States  <=50K              0
# 43350            40.0        United-States  <=50K              0
# 43375            40.0        United-States  <=50K              0
# 43398             8.0          El-Salvador  <=50K              0
# 43438            40.0        United-States  <=50K              0
# 43501            60.0        United-States   >50K              1
# 43503            40.0        United-States  <=50K              0
# 43563            38.0        United-States  <=50K              0
# 43590            40.0        United-States  <=50K              0
# 43599            40.0                South  <=50K              0
# 43651            40.0                Japan  <=50K              0
# 43727            50.0        United-States  <=50K              0
# 43793            40.0                 Laos  <=50K              0
# 43876            40.0        United-States  <=50K              0
# 44104            40.0        United-States  <=50K              0
# 44132            40.0        United-States  <=50K              0
# 44313            50.0        United-States  <=50K              0
# 44360            35.0        United-States  <=50K              0
# 44671            30.0        United-States  <=50K              0
# 44839            69.0              Germany   >50K              1
# 44849            55.0        United-States  <=50K              0
# 44957            15.0        United-States  <=50K              0
# 45006            42.0        United-States  <=50K              0
#
#        capital-gain-digitized  capital-loss-digitized  \
# 6                         0.0                     0.0
# 162                       0.0                     0.0
# 322                       0.0                     0.0
# 337                       0.0                     0.0
# 400                       1.0                     0.0
# 428                       0.0                     0.0
# 447                       0.0                     0.0
# 448                       0.0                     0.0
# 471                       0.0                     6.0
# 574                       0.0                     0.0
# 706                       0.0                     0.0
# 855                       0.0                     0.0
# 949                       0.0                     0.0
# 1007                      0.0                     0.0
# 1232                      0.0                     0.0
# 1359                      0.0                     0.0
# 1388                      0.0                     0.0
# 1626                      0.0                     0.0
# 1639                      4.0                     0.0
# 1643                      0.0                     0.0
# 1782                      0.0                     0.0
# 1819                      6.0                     0.0
# 1839                      0.0                     0.0
# 1851                      0.0                     0.0
# 1887                      0.0                     0.0
# 1937                      0.0                     0.0
# 2129                      0.0                     0.0
# 2152                      0.0                     0.0
# 2190                      0.0                     0.0
# 2300                      0.0                     9.0
# ...                       ...                     ...
# 42667                     0.0                     0.0
# 42674                     0.0                     0.0
# 42700                     0.0                     0.0
# 42743                    13.0                     0.0
# 42845                     0.0                     0.0
# 42956                     0.0                     0.0
# 42962                     5.0                     0.0
# 43128                     0.0                     0.0
# 43350                     0.0                     0.0
# 43375                     0.0                     0.0
# 43398                     0.0                     0.0
# 43438                     0.0                     0.0
# 43501                     3.0                     0.0
# 43503                     0.0                     0.0
# 43563                     0.0                     0.0
# 43590                     0.0                     0.0
# 43599                     0.0                     0.0
# 43651                     0.0                     0.0
# 43727                     0.0                     0.0
# 43793                     0.0                     0.0
# 43876                     0.0                     0.0
# 44104                     0.0                     0.0
# 44132                     0.0                     0.0
# 44313                     0.0                     0.0
# 44360                     0.0                     0.0
# 44671                     0.0                     0.0
# 44839                     0.0                     0.0
# 44849                     0.0                     0.0
# 44957                     0.0                     0.0
# 45006                     1.0                     0.0
#
#        hours-per-week-digitized
# 6                           1.0
# 162                         2.0
# 322                         2.0
# 337                         5.0
# 400                         4.0
# 428                         4.0
# 447                         4.0
# 448                         2.0
# 471                         4.0
# 574                         4.0
# 706                         4.0
# 855                         4.0
# 949                         5.0
# 1007                        6.0
# 1232                        4.0
# 1359                        4.0
# 1388                        4.0
# 1626                        4.0
# 1639                        4.0
# 1643                        4.0
# 1782                        4.0
# 1819                        4.0
# 1839                        5.0
# 1851                        5.0
# 1887                        4.0
# 1937                        3.0
# 2129                        4.0
# 2152                        4.0
# 2190                        4.0
# 2300                        6.0
# ...                         ...
# 42667                       4.0
# 42674                       4.0
# 42700                       4.0
# 42743                       6.0
# 42845                       1.0
# 42956                       4.0
# 42962                       4.0
# 43128                       3.0
# 43350                       4.0
# 43375                       4.0
# 43398                       0.0
# 43438                       4.0
# 43501                       6.0
# 43503                       4.0
# 43563                       3.0
# 43590                       4.0
# 43599                       4.0
# 43651                       4.0
# 43727                       5.0
# 43793                       4.0
# 43876                       4.0
# 44104                       4.0
# 44132                       4.0
# 44313                       5.0
# 44360                       3.0
# 44671                       3.0
# 44839                       6.0
# 44849                       5.0
# 44957                       1.0
# 45006                       4.0
#
# [552 rows x 18 columns]

# %% [markdown]
# **observations**
#  * Married-AF-spouse = Armed Forces, Married-civ-spouse = Civilian
#  * see how 'Married-civ-spouse' earns way more than any other category? We are dealing with **househould** income!
#  * So the person listed is the bread winner of the household? Do we have people from the same family?

# %% [markdown]
# ###  relationship

# %%
grouped = data.groupby(['relationship', 'income'])['income'].agg('count')
grouped = grouped.unstack()   # very important trick
display(grouped)     # print won't work here
# Out:
# income           <=50K  >50K
# relationship
#  Husband         10159  8507
#  Not-in-family   10474  1228
#  Other-relative   1299    50
#  Own-child        6521   105
#  Unmarried        4486   302
#  Wife             1075  1016

# %%
fig = plt.figure(figsize = (4,4))
grouped.plot.bar(stacked=True, color=['red','navy'])
plt.xticks(rotation=20)
plt.show()

# %%
data[(data['relationship']==' Own-child')]
# Out:
#        age          workclass education_level  education-num  \
# 12      23            Private       Bachelors           13.0
# 15      25   Self-emp-not-inc         HS-grad            9.0
# 25      19            Private         HS-grad            9.0
# 29      20            Private    Some-college           10.0
# 30      45            Private       Bachelors           13.0
# 31      30        Federal-gov    Some-college           10.0
# 34      21            Private    Some-college           10.0
# 64      19            Private    Some-college           10.0
# 65      31            Private       Bachelors           13.0
# 69      27            Private         HS-grad            9.0
# 71      18            Private            11th            7.0
# 78      53            Private         HS-grad            9.0
# 91      32        Federal-gov         HS-grad            9.0
# 95      20            Private    Some-college           10.0
# 98      30            Private            11th            7.0
# 105     36            Private         HS-grad            9.0
# 111     21            Private    Some-college           10.0
# 113     30            Private       Bachelors           13.0
# 115     19            Private    Some-college           10.0
# 117     20            Private    Some-college           10.0
# 128     20            Private    Some-college           10.0
# 131     27            Private    Some-college           10.0
# 132     19            Private    Some-college           10.0
# 142     21            Private         HS-grad            9.0
# 155     18            Private            11th            7.0
# 163     21            Private         HS-grad            9.0
# 165     18            Private         HS-grad            9.0
# 190     18            Private            11th            7.0
# 194     17            Private            11th            7.0
# 209     18            Private         HS-grad            9.0
# ...    ...                ...             ...            ...
# 44976   18            Private            12th            8.0
# 44978   23            Private    Some-college           10.0
# 44983   30            Private       Bachelors           13.0
# 44988   25            Private         HS-grad            9.0
# 44992   17            Private            10th            6.0
# 45003   30          Local-gov       Assoc-voc           11.0
# 45008   17            Private            11th            7.0
# 45012   22       Self-emp-inc       Bachelors           13.0
# 45026   24            Private         7th-8th            4.0
# 45038   32            Private         Masters           14.0
# 45053   20            Private    Some-college           10.0
# 45057   30          Local-gov    Some-college           10.0
# 45064   18          State-gov         HS-grad            9.0
# 45068   19            Private    Some-college           10.0
# 45071   24            Private       Bachelors           13.0
# 45078   18            Private            11th            7.0
# 45092   23          Local-gov       Bachelors           13.0
# 45125   37            Private         Masters           14.0
# 45129   45            Private         HS-grad            9.0
# 45138   27            Private       Bachelors           13.0
# 45158   36            Private         HS-grad            9.0
# 45161   18            Private         HS-grad            9.0
# 45167   19            Private         HS-grad            9.0
# 45183   21            Private         HS-grad            9.0
# 45190   19            Private             9th            5.0
# 45199   23            Private         HS-grad            9.0
# 45206   22            Private    Some-college           10.0
# 45215   25            Private         HS-grad            9.0
# 45217   33            Private       Bachelors           13.0
# 45220   44            Private       Bachelors           13.0
#
#             marital-status          occupation relationship  \
# 12           Never-married        Adm-clerical    Own-child
# 15           Never-married     Farming-fishing    Own-child
# 25           Never-married        Craft-repair    Own-child
# 29           Never-married               Sales    Own-child
# 30                Divorced     Exec-managerial    Own-child
# 31      Married-civ-spouse        Adm-clerical    Own-child
# 34           Never-married   Machine-op-inspct    Own-child
# 64           Never-married      Prof-specialty    Own-child
# 65               Separated               Sales    Own-child
# 69           Never-married       Other-service    Own-child
# 71           Never-married       Other-service    Own-child
# 78                Divorced               Sales    Own-child
# 91           Never-married       Other-service    Own-child
# 95           Never-married        Tech-support    Own-child
# 98           Never-married   Handlers-cleaners    Own-child
# 105          Never-married   Machine-op-inspct    Own-child
# 111          Never-married       Other-service    Own-child
# 113          Never-married     Exec-managerial    Own-child
# 115          Never-married       Other-service    Own-child
# 117          Never-married        Adm-clerical    Own-child
# 128          Never-married               Sales    Own-child
# 131          Never-married               Sales    Own-child
# 132          Never-married       Other-service    Own-child
# 142          Never-married        Craft-repair    Own-child
# 155          Never-married   Handlers-cleaners    Own-child
# 163          Never-married        Craft-repair    Own-child
# 165          Never-married       Other-service    Own-child
# 190          Never-married               Sales    Own-child
# 194          Never-married               Sales    Own-child
# 209          Never-married               Sales    Own-child
# ...                    ...                 ...          ...
# 44976        Never-married       Other-service    Own-child
# 44978        Never-married        Adm-clerical    Own-child
# 44983        Never-married       Other-service    Own-child
# 44988        Never-married        Adm-clerical    Own-child
# 44992        Never-married       Other-service    Own-child
# 45003             Divorced        Adm-clerical    Own-child
# 45008        Never-married               Sales    Own-child
# 45012        Never-married   Handlers-cleaners    Own-child
# 45026   Married-civ-spouse     Farming-fishing    Own-child
# 45038        Never-married               Sales    Own-child
# 45053        Never-married        Adm-clerical    Own-child
# 45057        Never-married        Craft-repair    Own-child
# 45064        Never-married        Adm-clerical    Own-child
# 45068        Never-married               Sales    Own-child
# 45071        Never-married        Tech-support    Own-child
# 45078        Never-married        Craft-repair    Own-child
# 45092        Never-married      Prof-specialty    Own-child
# 45125        Never-married     Exec-managerial    Own-child
# 45129   Married-civ-spouse        Adm-clerical    Own-child
# 45138        Never-married      Prof-specialty    Own-child
# 45158        Never-married        Craft-repair    Own-child
# 45161        Never-married     Exec-managerial    Own-child
# 45167        Never-married       Other-service    Own-child
# 45183        Never-married   Handlers-cleaners    Own-child
# 45190        Never-married        Craft-repair    Own-child
# 45199        Never-married   Machine-op-inspct    Own-child
# 45206        Never-married        Craft-repair    Own-child
# 45215        Never-married       Other-service    Own-child
# 45217        Never-married      Prof-specialty    Own-child
# 45220             Divorced        Adm-clerical    Own-child
#
#                       race      sex  capital-gain  capital-loss  \
# 12                   White   Female           0.0           0.0
# 15                   White     Male           0.0           0.0
# 25                   White     Male           0.0           0.0
# 29                   Black     Male           0.0           0.0
# 30                   White     Male           0.0        1408.0
# 31                   White     Male           0.0           0.0
# 34                   White     Male           0.0           0.0
# 64                   White     Male           0.0           0.0
# 65                   Black   Female           0.0           0.0
# 69                   White     Male           0.0           0.0
# 71                   White   Female           0.0           0.0
# 78                   White   Female           0.0           0.0
# 91                   Black     Male           0.0           0.0
# 95                   White   Female           0.0           0.0
# 98                   White     Male           0.0           0.0
# 105                  White   Female           0.0           0.0
# 111                  White   Female           0.0           0.0
# 113                  Black     Male           0.0           0.0
# 115                  Black     Male           0.0           0.0
# 117                  White   Female           0.0        1719.0
# 128                  White     Male           0.0           0.0
# 131                  White   Female           0.0           0.0
# 132                  White     Male           0.0           0.0
# 142                  White     Male           0.0           0.0
# 155                  White     Male           0.0           0.0
# 163                  Black     Male           0.0           0.0
# 165                  White     Male           0.0           0.0
# 190                  White   Female           0.0           0.0
# 194                  White   Female           0.0           0.0
# 209                  White   Female           0.0           0.0
# ...                    ...      ...           ...           ...
# 44976                White   Female           0.0           0.0
# 44978                White     Male           0.0           0.0
# 44983                White   Female           0.0           0.0
# 44988                White   Female        2174.0           0.0
# 44992                White     Male           0.0           0.0
# 45003                White   Female           0.0           0.0
# 45008                White   Female           0.0           0.0
# 45012                White     Male           0.0           0.0
# 45026                White   Female           0.0           0.0
# 45038                White   Female           0.0           0.0
# 45053                White   Female           0.0           0.0
# 45057                White     Male           0.0           0.0
# 45064                Black   Female           0.0           0.0
# 45068                White   Female           0.0           0.0
# 45071                White     Male           0.0           0.0
# 45078                White     Male           0.0           0.0
# 45092                White   Female           0.0           0.0
# 45125                White     Male           0.0           0.0
# 45129                White   Female           0.0           0.0
# 45138                Black     Male           0.0           0.0
# 45158                Black     Male           0.0           0.0
# 45161   Asian-Pac-Islander   Female           0.0           0.0
# 45167                White   Female           0.0        1602.0
# 45183                White   Female           0.0           0.0
# 45190                White     Male           0.0           0.0
# 45199                White     Male           0.0           0.0
# 45206                White     Male           0.0           0.0
# 45215                White   Female           0.0           0.0
# 45217                White     Male           0.0           0.0
# 45220   Asian-Pac-Islander     Male        5455.0           0.0
#
#        hours-per-week  native-country income  income_binary  \
# 12               30.0   United-States  <=50K              0
# 15               35.0   United-States  <=50K              0
# 25               40.0   United-States  <=50K              0
# 29               44.0   United-States  <=50K              0
# 30               40.0   United-States  <=50K              0
# 31               40.0   United-States  <=50K              0
# 34               40.0   United-States  <=50K              0
# 64               32.0   United-States  <=50K              0
# 65               40.0   United-States  <=50K              0
# 69               40.0          Mexico  <=50K              0
# 71               22.0   United-States  <=50K              0
# 78               35.0   United-States  <=50K              0
# 91               40.0   United-States  <=50K              0
# 95               40.0   United-States  <=50K              0
# 98               40.0   United-States  <=50K              0
# 105              40.0   United-States  <=50K              0
# 111              40.0   United-States  <=50K              0
# 113              40.0         Germany  <=50K              0
# 115              35.0   United-States  <=50K              0
# 117              28.0   United-States  <=50K              0
# 128              20.0   United-States  <=50K              0
# 131              40.0   United-States  <=50K              0
# 132              30.0          Mexico  <=50K              0
# 142              35.0   United-States  <=50K              0
# 155              16.0   United-States  <=50K              0
# 163              40.0   United-States  <=50K              0
# 165              12.0   United-States  <=50K              0
# 190              40.0   United-States  <=50K              0
# 194              12.0   United-States  <=50K              0
# 209              40.0   United-States  <=50K              0
# ...               ...             ...    ...            ...
# 44976            12.0   United-States  <=50K              0
# 44978            40.0   United-States  <=50K              0
# 44983            24.0   United-States  <=50K              0
# 44988            40.0   United-States  <=50K              0
# 44992            25.0   United-States  <=50K              0
# 45003            40.0   United-States  <=50K              0
# 45008            10.0   United-States  <=50K              0
# 45012            40.0   United-States  <=50K              0
# 45026            45.0          Mexico  <=50K              0
# 45038            50.0   United-States  <=50K              0
# 45053            16.0   United-States  <=50K              0
# 45057            40.0   United-States  <=50K              0
# 45064            20.0   United-States  <=50K              0
# 45068            20.0   United-States  <=50K              0
# 45071            40.0   United-States  <=50K              0
# 45078            20.0   United-States  <=50K              0
# 45092            43.0   United-States  <=50K              0
# 45125            40.0   United-States   >50K              1
# 45129            15.0   United-States  <=50K              0
# 45138            40.0   United-States  <=50K              0
# 45158            40.0   United-States  <=50K              0
# 45161            15.0   United-States  <=50K              0
# 45167            20.0   United-States  <=50K              0
# 45183            30.0   United-States  <=50K              0
# 45190            20.0   United-States  <=50K              0
# 45199            40.0   United-States  <=50K              0
# 45206            40.0   United-States  <=50K              0
# 45215            40.0   United-States  <=50K              0
# 45217            40.0   United-States  <=50K              0
# 45220            40.0   United-States  <=50K              0
#
#        capital-gain-digitized  capital-loss-digitized  \
# 12                        0.0                     0.0
# 15                        0.0                     0.0
# 25                        0.0                     0.0
# 29                        0.0                     0.0
# 30                        0.0                     7.0
# 31                        0.0                     0.0
# 34                        0.0                     0.0
# 64                        0.0                     0.0
# 65                        0.0                     0.0
# 69                        0.0                     0.0
# 71                        0.0                     0.0
# 78                        0.0                     0.0
# 91                        0.0                     0.0
# 95                        0.0                     0.0
# 98                        0.0                     0.0
# 105                       0.0                     0.0
# 111                       0.0                     0.0
# 113                       0.0                     0.0
# 115                       0.0                     0.0
# 117                       0.0                     8.0
# 128                       0.0                     0.0
# 131                       0.0                     0.0
# 132                       0.0                     0.0
# 142                       0.0                     0.0
# 155                       0.0                     0.0
# 163                       0.0                     0.0
# 165                       0.0                     0.0
# 190                       0.0                     0.0
# 194                       0.0                     0.0
# 209                       0.0                     0.0
# ...                       ...                     ...
# 44976                     0.0                     0.0
# 44978                     0.0                     0.0
# 44983                     0.0                     0.0
# 44988                     1.0                     0.0
# 44992                     0.0                     0.0
# 45003                     0.0                     0.0
# 45008                     0.0                     0.0
# 45012                     0.0                     0.0
# 45026                     0.0                     0.0
# 45038                     0.0                     0.0
# 45053                     0.0                     0.0
# 45057                     0.0                     0.0
# 45064                     0.0                     0.0
# 45068                     0.0                     0.0
# 45071                     0.0                     0.0
# 45078                     0.0                     0.0
# 45092                     0.0                     0.0
# 45125                     0.0                     0.0
# 45129                     0.0                     0.0
# 45138                     0.0                     0.0
# 45158                     0.0                     0.0
# 45161                     0.0                     0.0
# 45167                     0.0                     8.0
# 45183                     0.0                     0.0
# 45190                     0.0                     0.0
# 45199                     0.0                     0.0
# 45206                     0.0                     0.0
# 45215                     0.0                     0.0
# 45217                     0.0                     0.0
# 45220                     2.0                     0.0
#
#        hours-per-week-digitized
# 12                          3.0
# 15                          3.0
# 25                          4.0
# 29                          4.0
# 30                          4.0
# 31                          4.0
# 34                          4.0
# 64                          3.0
# 65                          4.0
# 69                          4.0
# 71                          2.0
# 78                          3.0
# 91                          4.0
# 95                          4.0
# 98                          4.0
# 105                         4.0
# 111                         4.0
# 113                         4.0
# 115                         3.0
# 117                         2.0
# 128                         2.0
# 131                         4.0
# 132                         3.0
# 142                         3.0
# 155                         1.0
# 163                         4.0
# 165                         1.0
# 190                         4.0
# 194                         1.0
# 209                         4.0
# ...                         ...
# 44976                       1.0
# 44978                       4.0
# 44983                       2.0
# 44988                       4.0
# 44992                       2.0
# 45003                       4.0
# 45008                       1.0
# 45012                       4.0
# 45026                       4.0
# 45038                       5.0
# 45053                       1.0
# 45057                       4.0
# 45064                       2.0
# 45068                       2.0
# 45071                       4.0
# 45078                       2.0
# 45092                       4.0
# 45125                       4.0
# 45129                       1.0
# 45138                       4.0
# 45158                       4.0
# 45161                       1.0
# 45167                       2.0
# 45183                       3.0
# 45190                       2.0
# 45199                       4.0
# 45206                       4.0
# 45215                       4.0
# 45217                       4.0
# 45220                       4.0
#
# [6626 rows x 18 columns]

# %% [markdown]
# **Observations**
#  * People who are listed as 'Own-child' are single.
#  * 'Other-relative' might be grandparents.
#  * We can actually divide this feature into 'complete' and 'incomplete' where the former overlaps with 'Married'. Therefore we can **combine 'relationship' and 'Martial-Status'**

# %% [markdown]
# ###  occupation

# %%
grouped = data.groupby(['occupation', 'income'])['income'].agg('count')
grouped = grouped.unstack()   # very important trick
#display(grouped)     # print won't work here

fig = plt.figure(figsize = (4,4))
grouped.plot.bar(stacked=True, color=['red','navy'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **observation**
#  * another strong indicator

# %% [markdown]
# ###  race

# %%
grouped = data.groupby(['race', 'income'])['income'].agg('count')
grouped = grouped.unstack()   # very important trick
grouped['ratio'] = grouped['>50K']/(grouped['>50K'] + grouped['<=50K'])
#display(grouped)     # print won't work here

fig = plt.figure(figsize = (4,4))
grouped.plot.bar(stacked=True, color=['red','navy'])
plt.xticks(rotation=45)
plt.show()

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize = (12,4))

grouped.plot.bar(y = ['<=50K', '>50K'], stacked=True, color=['orange','cyan'], ax = ax0)
ax0.set_xticklabels(grouped.index, rotation=45)
for i, race in enumerate(grouped.index):
    proportion = round(100*grouped.loc[race].sum()/grouped[['<=50K', '>50K']].sum().sum(), 1)
    ax0.annotate('{}%'.format(proportion), xy=(i*1 - 0.1, proportion*400+1000))
grouped.plot.bar(y = 'ratio', color='cyan', ax = ax1)
ax1.set_xticklabels(grouped.index, rotation=45)
plt.show()

# %% [markdown]
# Where are all the **hispanics**? Let's take a look at the races of people from a latino american country.

# %%
data[data['native-country']==' Honduras']
# Out:
#        age          workclass education_level  education-num  \
# 48      47            Private     Prof-school           15.0
# 657     36          Local-gov       Bachelors           13.0
# 6413    47            Private         HS-grad            9.0
# 6667    58          State-gov         HS-grad            9.0
# 11487   26       Self-emp-inc         HS-grad            9.0
# 15704   31            Private         1st-4th            2.0
# 16272   18            Private         5th-6th            3.0
# 23858   41       Self-emp-inc    Some-college           10.0
# 25127   28            Private    Some-college           10.0
# 25274   31            Private    Some-college           10.0
# 25731   19            Private            11th            7.0
# 30069   30   Self-emp-not-inc            11th            7.0
# 31203   48            Private    Some-college           10.0
# 31861   29          State-gov       Bachelors           13.0
# 35405   26            Private            10th            6.0
# 38155   61            Private         5th-6th            3.0
# 39046   25            Private         5th-6th            3.0
# 39362   32            Private    Some-college           10.0
# 44209   40            Private         HS-grad            9.0
#
#                marital-status          occupation     relationship    race  \
# 48         Married-civ-spouse      Prof-specialty             Wife   White
# 657                  Divorced        Adm-clerical        Unmarried   White
# 6413                 Divorced        Adm-clerical        Unmarried   White
# 6667    Married-spouse-absent       Other-service        Unmarried   Black
# 11487               Separated               Sales        Unmarried   White
# 15704               Separated   Handlers-cleaners        Unmarried   White
# 16272           Never-married   Handlers-cleaners   Other-relative   White
# 23858                Divorced   Machine-op-inspct    Not-in-family   White
# 25127           Never-married     Protective-serv        Own-child   White
# 25274           Never-married     Exec-managerial    Not-in-family   White
# 25731           Never-married               Sales    Not-in-family   White
# 30069   Married-spouse-absent        Craft-repair    Not-in-family   White
# 31203               Separated        Craft-repair        Unmarried   White
# 31861      Married-civ-spouse      Prof-specialty          Husband   White
# 35405           Never-married        Craft-repair   Other-relative   White
# 38155      Married-civ-spouse   Machine-op-inspct             Wife   White
# 39046                Divorced       Other-service        Unmarried   Other
# 39362                Divorced               Sales        Unmarried   Black
# 44209           Never-married     Priv-house-serv   Other-relative   Black
#
#            sex  capital-gain  capital-loss  hours-per-week native-country  \
# 48      Female           0.0        1902.0            60.0       Honduras
# 657     Female           0.0           0.0            35.0       Honduras
# 6413      Male           0.0           0.0            40.0       Honduras
# 6667    Female           0.0           0.0            40.0       Honduras
# 11487   Female           0.0           0.0            20.0       Honduras
# 15704     Male           0.0           0.0            35.0       Honduras
# 16272     Male           0.0           0.0            30.0       Honduras
# 23858   Female           0.0           0.0            40.0       Honduras
# 25127     Male           0.0           0.0            40.0       Honduras
# 25274     Male           0.0           0.0            45.0       Honduras
# 25731   Female           0.0           0.0            40.0       Honduras
# 30069     Male           0.0           0.0            30.0       Honduras
# 31203     Male        1506.0           0.0            40.0       Honduras
# 31861     Male           0.0           0.0            40.0       Honduras
# 35405     Male           0.0           0.0            24.0       Honduras
# 38155   Female           0.0           0.0            37.0       Honduras
# 39046   Female           0.0           0.0            20.0       Honduras
# 39362   Female           0.0        1138.0            40.0       Honduras
# 44209   Female           0.0           0.0            40.0       Honduras
#
#       income  income_binary  capital-gain-digitized  capital-loss-digitized  \
# 48      >50K              1                     0.0                     9.0
# 657    <=50K              0                     0.0                     0.0
# 6413   <=50K              0                     0.0                     0.0
# 6667   <=50K              0                     0.0                     0.0
# 11487  <=50K              0                     0.0                     0.0
# 15704  <=50K              0                     0.0                     0.0
# 16272  <=50K              0                     0.0                     0.0
# 23858  <=50K              0                     0.0                     0.0
# 25127  <=50K              0                     0.0                     0.0
# 25274  <=50K              0                     0.0                     0.0
# 25731  <=50K              0                     0.0                     0.0
# 30069  <=50K              0                     0.0                     0.0
# 31203  <=50K              0                     0.0                     0.0
# 31861   >50K              1                     0.0                     0.0
# 35405  <=50K              0                     0.0                     0.0
# 38155  <=50K              0                     0.0                     0.0
# 39046  <=50K              0                     0.0                     0.0
# 39362  <=50K              0                     0.0                     5.0
# 44209  <=50K              0                     0.0                     0.0
#
#        hours-per-week-digitized
# 48                          6.0
# 657                         3.0
# 6413                        4.0
# 6667                        4.0
# 11487                       2.0
# 15704                       3.0
# 16272                       3.0
# 23858                       4.0
# 25127                       4.0
# 25274                       4.0
# 25731                       4.0
# 30069                       3.0
# 31203                       4.0
# 31861                       4.0
# 35405                       2.0
# 38155                       3.0
# 39046                       2.0
# 39362                       4.0
# 44209                       4.0

# %% [markdown]
# **Observations**
#  * 'Hispanic' is NOT considered as a race (https://en.wikipedia.org/wiki/Hispanic)
#  * Current racial distribution in the US from national [demographics](https://statisticalatlas.com/United-States/Race-and-Ethnicity).
#  * Asians are most likely to have income great than 50K, trailled by Whites.

# %% [markdown]
# ###  Sex

# %%
grouped = data.groupby(['sex', 'income'])['income'].agg('count')
grouped = grouped.unstack()   # very important trick
#grouped['ratio'] = grouped['>50K']/(grouped['>50K'] + grouped['<=50K'])
#display(grouped)     # print won't work here

fig = plt.figure(figsize = (4,4))
grouped.plot.bar(stacked=True, color=['orange','cyan'])
for i, sex in enumerate(grouped.index):
    proportion = round(100*grouped.loc[sex].sum()/grouped[['<=50K', '>50K']].sum().sum(), 1)
    ax0.annotate(proportion, xy=(i*10, proportion))
plt.xticks(rotation=45)
plt.show()

# %%
data['marital-status']
# Out:
# 0                 Never-married
# 1            Married-civ-spouse
# 2                      Divorced
# 3            Married-civ-spouse
# 4            Married-civ-spouse
# 5            Married-civ-spouse
# 6         Married-spouse-absent
# 7            Married-civ-spouse
# 8                 Never-married
# 9            Married-civ-spouse
# 10           Married-civ-spouse
# 11           Married-civ-spouse
# 12                Never-married
# 13                Never-married
# 14           Married-civ-spouse
# 15                Never-married
# 16                Never-married
# 17           Married-civ-spouse
# 18                     Divorced
# 19           Married-civ-spouse
# 20                    Separated
# 21           Married-civ-spouse
# 22           Married-civ-spouse
# 23                     Divorced
# 24           Married-civ-spouse
# 25                Never-married
# 26                     Divorced
# 27           Married-civ-spouse
# 28                Never-married
# 29                Never-married
#                   ...
# 45192                  Divorced
# 45193             Never-married
# 45194        Married-civ-spouse
# 45195        Married-civ-spouse
# 45196             Never-married
# 45197        Married-civ-spouse
# 45198        Married-civ-spouse
# 45199             Never-married
# 45200                  Divorced
# 45201        Married-civ-spouse
# 45202                   Widowed
# 45203             Never-married
# 45204        Married-civ-spouse
# 45205        Married-civ-spouse
# 45206             Never-married
# 45207                   Widowed
# 45208                 Separated
# 45209             Never-married
# 45210                  Divorced
# 45211        Married-civ-spouse
# 45212        Married-civ-spouse
# 45213        Married-civ-spouse
# 45214        Married-civ-spouse
# 45215             Never-married
# 45216                  Divorced
# 45217             Never-married
# 45218                  Divorced
# 45219        Married-civ-spouse
# 45220                  Divorced
# 45221        Married-civ-spouse
# Name: marital-status, Length: 45222, dtype: object

# %%
tmp = data[data['marital-status'].isin([' Married-civ-spouse', ' Married-af-spouse'])]
grouped = tmp.groupby(['sex', 'income'])['income'].agg('count')
grouped = grouped.unstack()   # very important trick
#grouped['ratio'] = grouped['>50K']/(grouped['>50K'] + grouped['<=50K'])
#display(grouped)     # print won't work here

fig = plt.figure(figsize = (4,4))
grouped.plot.bar(stacked=True, color=['orange','cyan'])

# %% [markdown]
# **Observations**
#  * apparently, males have better chance to make income greater than 50K.
#  * however, when grouped by marital status, they are very similar. A lotta single moms are not doing well!

# %% [markdown]
# ###  Native Country

# %%
grouped = data.groupby(['native-country', 'income'])['income'].agg('count')
grouped = grouped.unstack()   # very important trick
#grouped['ratio'] = grouped['>50K']/(grouped['>50K'] + grouped['<=50K'])
#display(grouped)     # print won't work here

fig = plt.figure(figsize = (4,4))
grouped.plot.bar(stacked=True, color=['orange','cyan'])
plt.xticks(rotation=90)
plt.show()

# %%
# what are ratio between '>50K' and '<=50K' for people of US origin
grouped.loc[' United-States'][1]/grouped.loc[' United-States'].sum()
# Out:
# 0.25302722076915624

# %% [markdown]
# **Observations**
#  * Over 90% of the samples are US citizens
#  * The ratio of income classes are similar between people of US origin and people from all origins.
#  * The correlation between country and race? If there's a strong correlation and considering last observation, we may safely ignore this feature.

# %% [markdown]
# ### Univariate Analysis Summary

# %% [markdown]
# | Step               	| Observation                                                                                                                                                                                                                       	| Idea                                                                                                                           	|
# |--------------------	|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------	|--------------------------------------------------------------------------------------------------------------------------------	|
# | **data overview**  	| 45222x14, 5 numerical, 9 categorical<br>no missing or ill-formated<br>target variable is skewed (~75% '<50K')                                                                                                                     	| use part of the data for balanced training?                                                                                    	|
# | **ages**           	| people younger than 20 or older than 70 make less than the rest of the population                                                                                                                                                 	|                                                                                                                                	|
# | **education**      	| _education-level_ and _education-num_ carry the same information<br>higher educational level, higher chance of earning more than 50K                                                                                              	|                                                                                                                                	|
# | **capitals**       	| **net** income from capital investment<br>is not a good indicator for income classification<br>The ratios of income classes are quite different when capital is not zero<br>outliers with high gain but low income and vice versa 	| feature engineering to combine gain and loss so that we can extract more info?<br>ignore zero values or create a new category? 	|
# | **hours-per-week** 	| more than 40 hours, higher incomes                                                                                                                                                                                                	| correlated with occupation?                                                                                                    	|
# | **workclass**      	| 'self-emp-inc' has the highest chance of '>50K'                                                                                                                                                                                   	| 'without-pay' and no 'capital-gain' but '>50K', outlier?                                                                       	|
# | **marital-status** 	| We are dealing with **househould** income                                                                                                                                                                                         	| Do we have people from the same family? Assuming not?                                                                          	|
# | **relationship**   	| People who are listed as 'Own-child' are single<br>'Other-relative' might be grandparents                                                                                                                                         	| may combine 'relationship' and 'Martial-Status'                                                                                	|
# | **occupation**     	| strong indicator                                                                                                                                                                                                                  	| combine into fewer groups?                                                                                                     	|
# | **race**           	| Hispanic is not a race<br>Asians are most likely to have income great than 50K, trailled by Whites.                                                                                                                               	|                                                                                                                                	|
# | **sex**            	| male more likely to higher income<br>martial status matters a lot                                                                                                                                                                 	| combine with martial status?                                                                                                                               	|
# | **native-country** 	| over 90% are from USA<br>The ratio of income classes are similar between people of US origin and people from all origins                                                                                                          	| can be ignored?                                                                                                                	|
